# %%
from marks import tamil

# %%
tamil.subject()
# Out:
# Enter the Marks: 57
# Enter the Marks: 67
# Enter the Marks: 8
# Enter the Marks: 89
# Very Good
# Very Good
# Need to improve
# Excellent
# 'Excellent'
