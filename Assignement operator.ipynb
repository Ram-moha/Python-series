# %%
num1Ram=30
num2DD=40
num3Kan=60
add=num1Ram+num2DD+num3Kan
print(add)
# Out:
# 130

# %%
num4CC=50
num5WW=30
num6YY=80
sub=num4CC-num5WW-num6YY

# %%
print(sub)
# Out:
# -60

# %%
irstName="Ram Mohan"
print(irstName)
# Out:
# Ram Mohan

# %%
irstName="Ram Mohan"
print(irstName)
# Out:
# Ram Mohan

# %%
firstName="Ram Mohan"

# %%
print(firstName)
# Out:
# Ram Mohan

# %%
F2Name="F1 Car race"
print(F2Name)
# Out:
# F1 Car race

# %%
Ben10value=100
power20value=133
fast30value=160
add=Ben10value+power20value+fast30value
print(add)
# Out:
# 393

# %%
eleven11=134
time13=156
series=190
add=eleven11+time13+series
print(add)
# Out:
# 480

# %%
print("The Addition of two number")
num1=10
print("The number 1:", num1)
num2=20
print("The number 2:", num2)
print("The number:", num1+num2)
# Out:
# The Addition of two number
# The number 1: 10
# The number 2: 20
# The number: 30

# %%
num1=int(input("Enter the Value:"))
# Out:
# Enter the Value: 56

# %%
num2=int(input("Enter the Value:"))
# Out:
# Enter the Value: 43

# %%
add=num1+num2
print(add)
# Out:
# 99

# %%
num3=int(input("The age of Men:"))
num4=int(input("The age of Girl:"))
add=num3+num4
print(add)
# Out:
# The age of Men: 30
# The age of Girl: 26
# 56

# %%
num5=int(input("The Iron Man:"))
num6=int(input("The Marvel:"))
total=num5+num6
print(total)
# Out:
# The Iron Man: 2
# The Marvel: 3
# 5
