# %%
print("Wlcome to python world")
# Out:
# Wlcome to python world

# %%
print("welcome to pythin world")
# Out:
# welcome to pythin world

# %%
print ("wlcome to IT park")
# Out:
# wlcome to IT park

# %%
print("wlecome to tamilnadu:")
# Out:
# wlecome to tamilnadu:

# %%
print("Power of AI")
# Out:
# Power of AI

# %%
print("terminal")
# Out:
# terminal

# %%
print("power source")
# Out:
# power source

# %%
print("python developer")
# Out:
# python developer
