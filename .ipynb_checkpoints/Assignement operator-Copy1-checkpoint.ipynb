# %%
num1Ram=30
num2DD=40
num3Kan=60
add=num1Ram+num2DD+num3Kan
print(add)
# Out:
# 130

# %%
num4CC=50
num5WW=30
num6YY=80
sub=num4CC-num5WW-num6YY

# %%
print(sub)
# Out:
# -60

# %%
First Name="Ram Mohan"
print(Frist Name)
# Out:
#   Cell In[6], line 1
#     First Name="Ram Mohan"
#           ^
# SyntaxError: invalid syntax

# %%
3FirstName="Ram Mohan"
print(3FirstName)
# Out:
#   Cell In[7], line 1
#     3FirstName="Ram Mohan"
#     ^
# SyntaxError: invalid decimal literal

# %%
firstName="Ram Mohan"

# %%
print(firstName)
# Out:
# Ram Mohan

# %%
F2Name="F1 Car race"
print(F2Name)
# Out:
# F1 Car race
